# %% [markdown]
# # NAME: HIMANSHU MISHRA | ROLL NO: 180293 | ASSIGNMENT 1 | CS771A
#
#
#
#
# # QUESTION NO. 1

# %% [markdown]
# # Import required libraries i.e numpy, pandas and matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Providing feeding header name to the list named "headers"

# %%
# create headers list
headers = ["symboling", "normalized-losses", "make", "fuel-type", "aspiration", "num-of-doors", "body-style",
           "drive-wheels", "engine-location", "wheel-base", "length", "width", "height", "curb-weight", "engine-type",
           "num-of-cylinders", "engine-size", "fuel-system", "bore", "stroke", "compression-ratio",
           "horsepower", "peak-rpm", "city-mpg", "highway-mpg", "price"]
print("headers\n", headers)
# Out:
# headers
#  ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

# %% [markdown]
# Reading and printing available data

# %%
#import data
df = pd.read_csv("data1/imports-85.data", names = headers)
df.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# # Missing Data
# Identifing missing value and converting them into NaN

# %%
df.replace("?", np.nan, inplace = True)
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# Manupulating and checking the missing data in the provided table

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False               True  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False              False  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0       False         False            False       False  ...        False
# 1       False         False            False       False  ...        False
# 2       False         False            False       False  ...        False
# 3       False         False            False       False  ...        False
# 4       False         False            False       False  ...        False
#
# ...

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# symboling
# False    205
# Name: symboling, dtype: int64
#
# normalized-losses
# False    164
# True      41
# Name: normalized-losses, dtype: int64
#
# make
# False    205
# Name: make, dtype: int64
#
# fuel-type
# False    205
# Name: fuel-type, dtype: int64
#
# aspiration
# False    205
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    203
# True       2
# Name: num-of-doors, dtype: int64
#
# body-style
# False    205
# Name: body-style, dtype: int64
#
# drive-wheels
# False    205
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    205
# Name: engine-location, dtype: int64
#
# wheel-base
# False    205
# Name: wheel-base, dtype: int64
#
# length
# False    205
# Name: length, dtype: int64
#
# width
# False    205
# Name: width, dtype: int64
#
# height
# False    205
# Name: height, dtype: int64
#
# curb-weight
# False    205
# Name: curb-weight, dtype: int64
#
# engine-type
# False    205
# Name: engine-type, dtype: int64
#
# num-of-cylinders
# ...

# %% [markdown]
# # Dealing with Missing data
#
# 1)Drop Data
#
# a. drop the whole row
#
# b. drop the whole column
#
# 2)Replace Data
#
# a. replace it by mean
#
# b. replace it by frequency
#
# c. replace it based on other functions

# %% [markdown]
# # Replace by mean:
#
#     "normalized-losses": 41 missing data, replaced with mean
#     "stroke": 4 missing data, replaced mean
#     "bore": 4 missing data, replaced with mean
#     "horsepower": 2 missing data, replaced them with mean
#     "peak-rpm": 2 missing data, replaced with mean
#
# # Replace by frequency:
#
#     "num-of-doors": 2 missing data, replace them with "four".
#         Reason: 84% sedans is four doors. Since four doors is most frequent, it is most likely to occur

# %%
avg_norm_loss = df["normalized-losses"].astype("float").mean(axis=0)
print("Average of normalized-losses:", avg_norm_loss)
# Out:
# Average of normalized-losses: 122.0

# %%
df["normalized-losses"].replace(np.nan,avg_norm_loss,inplace=True)

# %%
avg_bore = df["bore"].astype("float").mean(axis=0)
print("Average of Bore Values:",avg_bore)
# Out:
# Average of Bore Values: 3.3297512437810957

# %%
df["bore"].replace(np.nan,avg_bore,inplace=True)

# %%
avg_stroke = df["stroke"].astype("float").mean(axis=0)
print("Average of Stroke Values:",avg_bore)
# Out:
# Average of Stroke Values: 3.3297512437810957

# %%
df["stroke"].replace(np.nan,avg_stroke,inplace = True)

# %%
avg_horsepower = df['horsepower'].astype("float").mean(axis=0)
print("Average horsepower:", avg_horsepower)
# Out:
# Average horsepower: 104.25615763546799

# %%
df['horsepower'].replace(np.nan, avg_horsepower, inplace=True)

# %%
avg_peakrpm=df['peak-rpm'].astype('float').mean(axis=0)
print("Average peak rpm:", avg_peakrpm)
# Out:
# Average peak rpm: 5125.369458128079

# %%
df['peak-rpm'].replace(np.nan, avg_peakrpm, inplace=True)

# %%
df['num-of-doors'].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %%
df['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
#replace the missing 'num-of-doors' values by the most frequent 
df['num-of-doors'].replace(np.nan,"four",inplace=True)

# %%
# simply drop whole row with NaN in "price" column
df.dropna(subset=["price"],axis=0,inplace=True)

# reset index, because we droped two rows
df.reset_index(drop=True,inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
df[["normalized-losses"]] = df[["normalized-losses"]].astype("int")
df[["price"]] = df[["price"]].astype("float")
df[["peak-rpm"]] = df[["peak-rpm"]].astype("float")

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# Describing how the data looks like

# %%
df.describe(include = 'all')
# Out:
#          symboling  normalized-losses    make fuel-type aspiration  \
# count   201.000000          201.00000     201       201        201
# unique         NaN                NaN      22         2          2
# top            NaN                NaN  toyota       gas        std
# freq           NaN                NaN      32       181        165
# mean      0.840796          122.00000     NaN       NaN        NaN
# std       1.254802           31.99625     NaN       NaN        NaN
# min      -2.000000           65.00000     NaN       NaN        NaN
# 25%       0.000000          101.00000     NaN       NaN        NaN
# 50%       1.000000          122.00000     NaN       NaN        NaN
# 75%       2.000000          137.00000     NaN       NaN        NaN
# max       3.000000          256.00000     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           201        201          201             201  201.000000  ...
# ...

# %% [markdown]
# Changing the datatype from object to category so that numerical value can be assigned

# %%
for col_name in df.columns:
    if(df[col_name].dtype == 'object'):
        df[col_name]= df[col_name].astype('category')
        df[col_name] = df[col_name].cat.codes

df.head(200)
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0            3                122     0          1           0             1
# 1            3                122     0          1           0             1
# 2            1                122     0          1           0             1
# 3            2                164     1          1           0             0
# 4            2                164     1          1           0             0
# ..         ...                ...   ...        ...         ...           ...
# 195         -1                 74    21          1           1             0
# 196         -1                 95    21          1           0             0
# 197         -1                 95    21          1           1             0
# 198         -1                 95    21          1           0             0
# 199         -1                 95    21          0           1             0
#
# ...

# %% [markdown]
# Firstly randomly deviding the data set into training data and test data in 70:30

# %%
shuffle_df = df.sample(frac=1)

# Define the size  train set 
train_size = int(0.7 * len(df))

# Spliting the dataset 
train_set = shuffle_df[:train_size]
test_set = shuffle_df[train_size:]

# %%
train_set.head()
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 113          0                161    13          0           1             0
# 161          1                168    19          1           0             1
# 137          0                102    18          1           0             0
# 22           1                118     4          1           1             1
# 10           0                192     2          1           0             0
#
#      body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 113           3             2                0       107.9  ...          152
# 161           3             2                0        94.5  ...           98
# 137           3             1                0        97.2  ...          108
# 22            2             1                0        93.7  ...           98
# 10            3             2                0       101.2  ...          108
#
# ...

# %% [markdown]
# Further dividng traning data into training data and validation data in 80:20

# %%
shuffle_train = train_set.sample(frac=1)

# Defining size for train set 
val_size = int(0.8 * len(train_set))

# Spliting dataset 
training_set = shuffle_train[:val_size]
validation_set = shuffle_train[val_size:]

# %%
validation_set.head()
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 179          2                122    20          1           0             1
# 133          2                104    17          1           1             0
# 70           0                122     9          1           0             0
# 102          3                194    12          1           1             1
# 14           0                122     2          1           0             0
#
#      body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 179           3             1                0        97.3  ...          109
# 133           3             1                0        99.1  ...          121
# 70            3             2                0       120.9  ...          308
# 102           2             2                0        91.3  ...          181
# 14            3             2                0       103.5  ...          209
#
# ...

# %% [markdown]
# Now dividing data into two part i.e first part containing the feature values and  second part containing the actual prices of the automobile
#
# Training set is divided into x_train and y_train
#
# Test set into x_test and y_test
#
# and Validation set into x_valid and y_valid

# %%
x_train = training_set.drop("price", axis=1)
y_train = training_set['price']

x_test = test_set.drop("price", axis=1)
y_test = test_set['price']

x_valid = validation_set.drop("price", axis=1)
y_valid = validation_set['price']

# %% [markdown]
# All the training, test and validation set is scaled between 0 to 1 so as to normalise the data

# %%
#scaling the dataset
x_train_scaled = ((x_train-x_train.min(axis=0))/(x_train.max(axis=0) - x_train.min(axis=0)))*1.0
x_test_scaled = ((x_test-x_test.min(axis=0))/(x_test.max(axis=0) - x_test.min(axis=0)))*1.0
x_valid_scaled = ((x_valid-x_valid.min(axis=0))/(x_valid.max(axis=0) - x_valid.min(axis=0)))*1.0

# %%
x_train_scaled.head()
# Out:
#      symboling  normalized-losses      make  fuel-type  aspiration  \
# 144        0.4           0.151515  0.857143        1.0         0.0
# 32         0.6           0.272727  0.238095        1.0         0.0
# 113        0.4           0.727273  0.619048        0.0         1.0
# 152        0.4           0.196970  0.904762        1.0         0.0
# 34         0.4           0.340909  0.238095        1.0         0.0
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  ...  \
# 144           0.0        1.00           0.0              0.0    0.355172  ...
# 32            1.0        0.50           0.5              0.0    0.244828  ...
# 113           0.0        0.75           1.0              0.0    0.734483  ...
# 152           0.0        0.75           0.5              0.0    0.313793  ...
# 34            0.0        0.75           0.5              0.0    0.341379  ...
#
#      num-of-cylinders  engine-size  fuel-system      bore    stroke  \
# ...

# %%
x_test_scaled.head()
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 27         0.2           0.235602  0.15        1.0         0.0           0.0
# 146        0.6           0.115183  0.90        1.0         0.0           1.0
# 16         0.4           0.298429  0.05        1.0         0.0           0.0
# 11         0.4           0.643979  0.05        1.0         0.0           1.0
# 100        0.4           0.225131  0.55        1.0         0.0           0.0
#
#      body-style  drive-wheels  engine-location  wheel-base  ...  \
# 27         1.00           0.5              0.0    0.605072  ...
# 146        0.50           0.5              0.0    0.329710  ...
# 16         0.75           1.0              0.0    0.847826  ...
# 11         0.75           1.0              0.0    0.528986  ...
# 100        0.75           0.5              0.0    0.500000  ...
#
#      num-of-cylinders  engine-size  fuel-system      bore    stroke  \
# ...

# %% [markdown]
# Reshaping the target variables

# %%
y_train = np.array(y_train)
y_valid = np.array(y_valid)

y_train = y_train.reshape(len(y_train),1)
y_valid = y_valid.reshape(len(y_valid),1)

y_pred = np.zeros(y_valid.shape)
y_train.shape, y_valid.shape,y_valid.shape
# Out:
# ((112, 1), (28, 1), (28, 1))

# %% [markdown]
# # KNN IMPLEMENTATION
# Assuming the K values to be 3. Looping over each point of the validation data set, to find the euclidian distance between the test point and train data points. Then, sorting the distance and finding the nearest 3 neighbours. Once obtained the y values of the nearest neighbours, taking the average of those values and adjusting the prediction the appropriate mean and to get the predicted target variable. Thus calculating the RMSE value.

# %%
x_valid_scaled = np.array(x_valid_scaled)
x_train_scaled = np.array(x_train_scaled)
x_test_scaled = np.array(x_test_scaled)
k = 3

for row in range(len(x_valid_scaled)):
    #finding the euclidian distance
    euclidian_distance = np.sqrt(np.sum((x_train_scaled - x_valid_scaled[row])**2, axis = 1 ))
    #pridicting the target
    y_pred[row] = y_train[np.argsort(euclidian_distance, axis = 0)[:k]].mean()
    
#Finding the root mean squared error 
RMSE = np.sqrt(np.mean((y_valid - y_pred)**2))
print("The validation set performence using root mean square error(RMSE):", RMSE)
# Out:
# The validation set performence using root mean square error(RMSE): 12075.389836948772

# %% [markdown]
# Testing the model with Test dataset

# %%
y_pred = np.zeros(y_test.shape)
# using the trained model to predict the target in test dataset.
for row in range(len(x_test_scaled)):
     #finding the euclidian distance
    euclidian_distance = np.sqrt(np.sum((x_train_scaled - x_test_scaled[row])**2, axis = 1 ))
    #pridicting the target
    y_pred[row] = y_train[np.argsort(euclidian_distance, axis = 0)[:k]].mean()
#Finding the root mean squared error 
RMSE = np.sqrt(np.mean((y_test - y_pred)**2))
print("The Test set performence using root mean square error(RMSE):", RMSE)
# Out:
# The Test set performence using root mean square error(RMSE): 4011.872167656577

# %% [markdown]
# # Finding Optimal k value using cross-validation
# The validation set RMSE value is calculated for each value of k between 0 to 50. The value of parameter k which provides the least RMSE validation error is selested as optimal k value for the data set.

# %%
k_list = [x for x in range(1,50,1)]

# Calculating the distance matrix using numpy
distance = np.sqrt(((x_train_scaled[:, :, None] - x_valid_scaled[:, :, None].T) ** 2).sum(1))

#Sorting each data points of the distance matrix to reduce computational effort 
sorted_distance = np.argsort(distance, axis = 0)

#The knn function takes in the sorted distance and returns the RMSE of the 
def knn(x_train_scaled,x_valid_scaled,y_train,y_valid,sorted_distance,k):
    y_pred = np.zeros(y_valid.shape)
    for row in range(len(x_valid_scaled)):
        
        #Transforming the y_train values to adjust the scale. 
        y_pred[row] = y_train[sorted_distance[:,row][:k]].mean()

    RMSE = np.sqrt(np.mean((y_valid - y_pred)**2))
    return RMSE

#Storing the RMSE values in a list for each k value 
rmse_list = []
for i in k_list:
    rmse_list.append(knn(x_train_scaled,x_valid_scaled,y_train,y_valid,sorted_distance,i))

# %%
#Finding the optimal K value
min_rmse_k_value = k_list[rmse_list.index(min(rmse_list))]

#Finding the lowest possible RMSE
optimal_RMSE = knn(x_train_scaled,x_valid_scaled,y_train,y_valid,sorted_distance,min_rmse_k_value)

print("The minimum RMSE value using optimal k value is:",optimal_RMSE)
print("The optimal value of k using cross-validation is:",min_rmse_k_value)
# Out:
# The minimum RMSE value using optimal k value is: 9021.9126571973
# The optimal value of k using cross-validation is: 11

# %% [markdown]
# Plotting RMSE vs K on validation set

# %%
#plotting RMSE vs K curve
curve = pd.DataFrame(rmse_list)
curve.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Retraining the Model using Lo Regularization

# %%
k_list = [x for x in range(1,50,1)]

# Calculating the distance matrix using numpy 
distance = np.sqrt(((x_train_scaled[:, :, None] - x_valid_scaled[:, :, None].T) ** 2).sum(1))

#Sorting each data points of the distance matrix to reduce computational effort 
sorted_distance = np.argsort(distance, axis = 0)

#The knn function takes in the sorted distance and returns the RMSE of the 
def knn(x_train_scaled,x_valid_scaled,y_train,y_valid,sorted_distance,k):
    y_pred = np.zeros(y_valid.shape)
    alpha = 6
    for row in range(len(x_valid_scaled)):
        
        #Transforming the y_train values to adjust the scale.
        y_val = np.array(y_train[sorted_distance[:,row][:k]])
        w = 0
        for i in range(len(y_val)):
            y_val[i] = y_val[i]*(k - i)**(alpha)
            w = w + (k-i)**(alpha);
        y_pred[row] = np.sum(y_val)/w

    RMSE = np.sqrt(np.mean((y_valid - y_pred)**2))
    return RMSE

#Storing the RMSE values in a list for each k value 
rmse_list = []
for i in k_list:
    rmse_list.append(knn(x_train_scaled,x_valid_scaled,y_train,y_valid,sorted_distance,i))

# %%
min_rmse_k_value = k_list[rmse_list.index(min(rmse_list))]

#Finding the lowest possible RMSE
optimal_RMSE = knn(x_train_scaled,x_valid_scaled,y_train,y_valid,sorted_distance,min_rmse_k_value)
print("The minimum RMSE valye using optimal k value is:",optimal_RMSE)
print("The optimal value of k using cross-validation is:",min_rmse_k_value)
# Out:
# The minimum RMSE valye using optimal k value is: 9806.082465549816
# The optimal value of k using cross-validation is: 49

# %%
#plotting RMSE vs K curve
curve = pd.DataFrame(rmse_list)
curve.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Commenting on the features dependencies

# %% [markdown]
# Yes, $Lo$ Regularisarion have improves generalization and have reduced the RMSE as well.
# # The most important features identified by the model for predicting prices

# %%
df.corr()
# Out:
#                    symboling  normalized-losses      make  fuel-type  \
# symboling           1.000000       4.662638e-01 -0.129645   0.196735
# normalized-losses   0.466264       1.000000e+00 -0.254356   0.101546
# make               -0.129645      -2.543563e-01  1.000000  -0.109330
# fuel-type           0.196735       1.015463e-01 -0.109330   1.000000
# aspiration         -0.054615      -6.910980e-03  0.071254  -0.408228
# num-of-doors        0.672344       3.613676e-01 -0.146172   0.186681
# body-style         -0.600333      -2.517751e-01  0.090621  -0.147654
# drive-wheels       -0.053056       3.172142e-01 -0.034844  -0.131096
# engine-location     0.212339       9.412733e-17  0.053312   0.040917
# wheel-base         -0.535987      -5.666124e-02  0.073930  -0.307237
# length             -0.365404       1.942356e-02  0.110468  -0.211187
# width              -0.242423       8.680206e-02 -0.005115  -0.244356
# height             -0.550160      -3.737370e-01  0.230754  -0.281578
# ...

# %% [markdown]
# # Wheel-base vs Price
#
# Let's calculate the Pearson Correlation Coefficient and P-value of 'wheel-base' and 'price'.

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(df['wheel-base'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5846418222655081  with a P-value of P = 8.076488270732989e-20

# %% [markdown]
# CONCLUSION:
#
# Since the p-value is < 0.001, the correlation between wheel-base and price is statistically significant, although the linear relationship isn't extremely strong (~0.585)
#
# # Horsepower vs Price
#
# Let's calculate the Pearson Correlation Coefficient and P-value of 'horsepower' and 'price'.

# %%
pearson_coef, p_value = stats.pearsonr(df['horsepower'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.31709776062603084  with a P-value of P =  4.506970534659629e-06

# %% [markdown]
# CONCLUSION:
#
# Since the p-value is < 0.001, the correlation between horsepower and price is statistically significant, and the linear relationship is quite strong (~0.809, close to 1)
#
# # Length vs Price
#
# Let's calculate the Pearson Correlation Coefficient and P-value of 'length' and 'price'.

# %%
pearson_coef, p_value = stats.pearsonr(df['width'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value )
# Out:
# The Pearson Correlation Coefficient is 0.7512653440522672  with a P-value of P = 9.20033551048217e-38

# %% [markdown]
# CONCLUSION:
#
# Since the p-value is < 0.001, the correlation between length and price is statistically significant, and the linear relationship is moderately strong (~0.691).
#
# # Width vs Price
#
# Let's calculate the Pearson Correlation Coefficient and P-value of 'width' and 'price':

# %%
pearson_coef, p_value = stats.pearsonr(df['curb-weight'], df['price'])
print( "The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8344145257702846  with a P-value of P =  2.1895772388936914e-53

# %% [markdown]
# CONCLUSION:
#
# Since the p-value is < 0.001, the correlation between width and price is statistically significant, and the linear relationship is quite strong (~0.751).
#
# # Curb-weight vs Price
#
# Let's calculate the Pearson Correlation Coefficient and P-value of 'curb-weight' and 'price':

# %%
pearson_coef, p_value = stats.pearsonr(df['curb-weight'], df['price'])
print( "The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8344145257702846  with a P-value of P =  2.1895772388936914e-53

# %% [markdown]
# CONCLUSION:
#
# Since the p-value is < 0.001, the correlation between curb-weight and price is statistically significant, and the linear relationship is quite strong (~0.834).
#
# # Engine-size vs Price
#
# Let's calculate the Pearson Correlation Coefficient and P-value of 'engine-size' and 'price':

# %%
pearson_coef, p_value = stats.pearsonr(df['engine-size'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8723351674455185  with a P-value of P = 9.265491622198389e-64

# %% [markdown]
# CONCLUSION:
#
# Since the p-value is < 0.001, the correlation between engine-size and price is statistically significant, and the linear relationship is very strong (~0.872).
#
# # Bore vs Price
#
# Let's calculate the Pearson Correlation Coefficient and P-value of 'bore' and 'price':

# %%
pearson_coef, p_value = stats.pearsonr(df['bore'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =  ", p_value )
# Out:
# The Pearson Correlation Coefficient is 0.5431553832626602  with a P-value of P =   8.049189483935489e-17

# %% [markdown]
# CONCLUSION:
#
# Since the p-value is < 0.001, the correlation between bore and price is statistically significant, but the linear relationship is only moderate (~0.521).
#
# We can relate the process for each 'City-mpg' and 'Highway-mpg':
#
# # City-mpg vs Price

# %%
pearson_coef, p_value = stats.pearsonr(df['city-mpg'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.6865710067844677  with a P-value of P =  2.321132065567674e-29

# %% [markdown]
# CONCLUSION:
#
# Since the p-value is < 0.001, the correlation between city-mpg and price is statistically significant, and the coefficient of ~ -0.687 shows that the relationship is negative and moderately strong.
#
# # Highway-mpg vs Price

# %%
pearson_coef, p_value = stats.pearsonr(df['highway-mpg'], df['price'])
print( "The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value )
# Out:
# The Pearson Correlation Coefficient is -0.7046922650589529  with a P-value of P =  1.7495471144477352e-31

# %% [markdown]
# CONCLUSION:
#
# Since the p-value is < 0.001, the correlation between highway-mpg and price is statistically significant, and the coefficient of ~ -0.705 shows that the relationship is negative and moderately strong.

# %% [markdown]
# # Most important features by the model are:
#
#
# 1) Length
#
# 2) Width
#
# 3) Curb-weight
#
# 4) Engine-size
#
# 5) Horsepower
#
# 6) City-mpg
#
# 7) Highway-mpg

# %% [markdown]
# The important features predicted by the model are very relevant to the real-world intuitions about the car prices.
# The car with larger dimensions, high milage, high horsepower and good engine size generally have high prices. The prices in real world are based on the value of these features to a large extent. So, the model significantly represents the real-world intuitions about car prices.

# %% [markdown]
# # QUESTION NO. 2

# %% [markdown]
# Import the data from the file

# %%
df = pd.read_csv('data1/adult.data',names = ['age','workclass','fnlwgt','education','education_num',
                                               'marital_status','occupation','relationship','race','sex',
                                               'capital_gain','capital_loss','hours_per_week','native_country','income'])

# %% [markdown]
# Checking the number of features and data sets provided

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %% [markdown]
# # Missing Data
# 1) Identifing missing value and converting them into NaN
#
# 2) Convert the column datatype 'object' to datatype 'category' so that numerical value can be assigned (feature extraction)

# %%
df.loc[14,'native_country']
df.replace(' ?', np.nan, inplace = True)
df.head(15)

df = df.apply(lambda x:x.fillna(x.value_counts().index[0])) 

# Convert the column datatype 'object' to datatype 'category' so that numerical value can be assigned
for col_name in df.columns:
    if(df[col_name].dtype == 'object'):
        df[col_name]= df[col_name].astype('category')
        df[col_name] = df[col_name].cat.codes

df.head(20)
# Out:
#     age  workclass  fnlwgt  education  education_num  marital_status  \
# 0    39          6   77516          9             13               4
# 1    50          5   83311          9             13               2
# 2    38          3  215646         11              9               0
# 3    53          3  234721          1              7               2
# 4    28          3  338409          9             13               2
# 5    37          3  284582         12             14               2
# 6    49          3  160187          6              5               3
# 7    52          5  209642         11              9               2
# 8    31          3   45781         12             14               4
# 9    42          3  159449          9             13               2
# 10   37          3  280464         15             10               2
# 11   30          6  141297          9             13               2
# 12   23          3  122272          9             13               4
# ...

# %% [markdown]
# Assigning value '-1' to those income columns, whose income is <=50 and '1' to those, whose income >= 50

# %%
df['income'] = df['income'].map({0:-1, 1:1}).astype(int)

# %% [markdown]
# # Training, Test and validation test
#
# Randomly dividing the data into training and test sets in 70:30 ratio
#
# Again dividing the training set into training data and validation data into 80:20 ratio

# %%
shuffle_df = df.sample(frac=1)

# Define the size for  train set 
train_size = int(0.7 * len(df))

# Split the dataset 
train_set = shuffle_df[:train_size]
test_set = shuffle_df[train_size:]

train_set.head()
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 24742   24          6  197731         11              9               2
# 7271    28          3  132686         15             10               2
# 11844   31          3  286406         11              9               4
# 21294   27          3   47907          9             13               4
# 30530   57          3  204816         12             14               0
#
#        occupation  relationship  race  sex  capital_gain  capital_loss  \
# 24742          13             0     4    1             0             0
# 7271            3             0     4    1             0             0
# 11844           3             1     4    1          3325             0
# 21294           0             1     4    0             0             0
# 30530           9             1     4    1             0             0
#
#        hours_per_week  native_country  income
# 24742              49              38       1
# ...

# %%
shuffle_train = train_set.sample(frac=1)

# Define the size for  train set 
val_size = int(0.8 * len(train_set))

# Split your dataset 
training_set = shuffle_train[:val_size]
validation_set = shuffle_train[val_size:]

# %% [markdown]
# # Decision Tree Implementation
# Splitting criteria: Information Gain: (Entropy)

# %%
x_train = training_set.drop("income", axis=1)
y_train = training_set['income']

x_test = test_set.drop("income", axis=1)
y_test = test_set['income']

x_valid = validation_set.drop("income", axis=1)
y_valid = validation_set['income']

# %% [markdown]
# Decision Tree class implementation

# %%
# Feature selection for Internal Node Criteria: Information gain
class Node:
    # A node stores its own depth (root = depth 0), its decision stump, its parent and child information
    # Leaf nodes also store a constant label that is assigned to every data point that reaches that leaf
    def __init__( self, depth = 0, stump = (0,0), parent = None ):
        self.depth = depth
        self.stump = stump
        self.parent = parent
        self.left = None
        self.right = None
        self.isLeaf = True
        self.label = 0
        
    def predict( self, data ):
        # If data reaches leaf, predict target rightaway
        
        if self.isLeaf:
            return self.label
        # Else go toward children to do the job
        else:
            if data[self.stump[0]] > self.stump[1]:
                return self.right.predict( data )
            else:
                return self.left.predict( data )
            
    # Get the Entropy of a node with nPos positive points and nNeg negative points
    def getEntropy( self, nPos, nNeg ):
        nTot = nPos + nNeg
        # Find the proportion of the positives and negatives in that node
        pPos = nPos/nTot
        pNeg = nNeg/nTot
        if(pPos==0 or pNeg==0):
            return float('inf')
        entropy = -1.0*(pPos*np.log(pPos)) - 1.0*(pNeg*np.log(pNeg))
        return entropy
            
    def getStump( self, X, y ):
        # data points present at this node
        n = len(y)
        bestObjective = 0
        cnt=0
        for i in range(len(y)):
            if y[i] == -1:
                cnt+=1
        Entropy = self.getEntropy(n-cnt,cnt)
        # For each of the features in the data
        for i in range( X.shape[1] ):
            # not to use same feature used by the parent node
            if self.parent is not None and i == self.parent.stump[0]:
                continue
            # Finding all values at which threshold for that feature camn be found
            candidateThresholds = np.sort( X[:, i] )
            idx = np.argsort( X[:, i] )
            # The cumulative sum trick used here since labels are binary 
            ySorted = y[idx]
            yCum = np.cumsum( ySorted )
            yCumRev = np.cumsum( ySorted[::-1] )[::-1]
            

            # For each possible threshold (except the ones at the extreme)
            for j in range( 1, candidateThresholds.size-1 ):
                Entropy_1 =  1.0 * self.getEntropy( (yCum[j] + j+1)/2, (j+1 - yCum[j])/2 )
                Entropy_2 =  1.0 * self.getEntropy( (yCumRev[j+1] + n-j-1)/2, (n-j-1 - yCumRev[j+1])/2 )
                if(Entropy_1 == float('inf') or Entropy_2 == float('inf')):
                    bestFeat = i
                    bestThresh = candidateThresholds[j]
                    break
                sz_1 = (yCum[j] + j+1)/2 + (j+1 - yCum[j])/2 
                sz_2 = (yCumRev[j+1] + n-j-1)/2 + (n-j-1 - yCumRev[j+1])/2
                
                candidateObjective = Entropy - ((sz_1 * Entropy_1)/n) - ((sz_2 * Entropy_2)/n)
                if candidateObjective > bestObjective:
                    bestObjective = candidateObjective
                    bestFeat = i
                    bestThresh = candidateThresholds[j]
        return (bestFeat, bestThresh)
            
    def train( self, X, y, maxLeafSize, maxDepth ):
        # If too few data points are present, or else if this node is too deep in the tree, make this a leaf
        if y.size < maxLeafSize or self.depth >= maxDepth:
            self.isLeaf = True
            self.label = np.mean( y )
        else:
            # This node will be split and hence it is not a leaf
            self.isLeaf = False
            # Get the best possible decision stump
            self.stump = self.getStump( X, y )
            self.left = Node( depth = self.depth + 1, parent = self )
            self.right = Node( depth = self.depth + 1, parent = self )
            # Find which points go to my left child and which go to my right child
            discriminant = X[:, self.stump[0]] - self.stump[1]
            # Train my two children recursively
            self.left.train( X[discriminant <= 0, :], y[discriminant <= 0], maxLeafSize, maxDepth )
            self.right.train( X[discriminant > 0, :], y[discriminant > 0], maxLeafSize, maxDepth )

class Tree:
    def __init__( self, maxLeafSize, maxDepth ):
        self.root = Node()
        self.maxLeafSize = maxLeafSize
        self.maxDepth = maxDepth 
        
    def predict( self, xt):
        return self.root.predict( np.array(xt) )
    
    def train( self, X, y ):
        self.root.train( X, y, self.maxLeafSize, self.maxDepth )

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

x_test = np.array(x_test)
y_test = np.array(y_test)

x_valid = np.array(x_valid)
y_valid = np.array(y_valid)

# %% [markdown]
# # Training the decision Tree
#
# maxLeafSize = 5, maxDepth = 4

# %%
DT = Tree( maxLeafSize = 4, maxDepth = 4 )
DT.train(x_train, y_train )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Validation Set Accuracy

# %%
#y_prid wiil contained the predicted class by the decision tree
y_prid = []
# iterating over all the validation data set
for i in range(len(x_valid)):
    #pridicting the target
    if(DT.predict(x_valid[i]) >= 0):
        y_prid.append(1)    
    else:
        y_prid.append(-1)
count = 0
# Validation set Accuration calculatiob by (number of correct predictions)/(total number of predictions)
for i in range(len(y_prid)):
    if(y_prid[i] == y_valid[i]):
        count = count + 1
print("Validation set Accuracy : ",count/len(y_prid))
# Out:
# Validation set Accuracy :  0.7479710462820794

# %% [markdown]
# # Optimizing tree hyperparameters using Cross Validation

# %%
##Optimising the dataset using cross validation
#initialing the parameters
BestAccuracy = -1.00
maxleaf = 0.0
maxdepth = 0.0
#iterating over possible values of maxLeafSize and maxDepth to get optimal vallue of hyperparameter
for i in range(4,8,1):
    for j in range(4,8,1):
        # training the tree for each iteration
        DT = Tree( maxLeafSize = i, maxDepth = j)
        DT.train(x_train, y_train)
        y_prid = []
        # predicting the target value for each case
        for k in range(len(x_valid)):
            if(DT.predict(x_valid[k]) >= 0):
                y_prid.append(1)
            else:
                y_prid.append(-1)
        count = 0
        for k in range(len(y_prid)):
            if(y_prid[k] == y_valid[k]):
                count = count + 1
        # storing optimal value for accuracy and hyperparameters
        if(BestAccuracy < count/len(y_prid)):
            BestAccuracy = count/len(y_prid)
            maxleaf = i
            maxdepth = j
print("Optimal value of MaxLeaf:", maxleaf)
print("Optimal value of MaxDepth:",maxdepth)
print("Optimal accuracy using cross validation:",BestAccuracy)
# Out:
# Optimal value of MaxLeaf: 4
# Optimal value of MaxDepth: 4
# Optimal accuracy using cross validation: 0.7479710462820794

# %% [markdown]
# # Calculating Test set accuracy
#   Using optimal value of maxleaf and maxdepth

# %%
y_prid = []
#predicting the test accuracy
DT = Tree( maxLeafSize = maxleaf, maxDepth = maxdepth)
DT.train(x_train, y_train)
for i in range(len(x_test)):
    if(DT.predict(x_test[i]) >= 0):
        y_prid.append(1)
    else:
        y_prid.append(-1)
count = 0
for i in range(len(y_test)):
    if(y_prid[i] == y_test[i]):
        count = count + 1
print("Test set Accuracy: ",count/len(y_test))
# Out:
# Test set Accuracy:  0.7627188043812059

# %% [markdown]
# # Creating stump using the LwP algorithm to decide thresholds

# %%
wBalance = 0.5
wPurity = 1.0
def getBalance( nLeft, nRight ):
    balance = max(nLeft, nRight)/min(nLeft, nRight) - 1
    return balance

# %% [markdown]
# Creating Tree Class for decision tree using LwPStump

# %%
# Feature selection for Internal Node Criteria: Information gain
class Node:
    # Leaf nodes also store a constant label that is assigned to every data point that reaches that leaf
    def __init__( self, depth = 0, stump = (0,0), parent = None ):
        self.depth = depth
        self.stump = stump
        self.parent = parent
        self.left = None
        self.right = None
        self.isLeaf = True
        self.label = 0
        
    def predict( self, data ):
        # If I am a leaf I can predict rightaway
        # May change this constant leaf action to something more interesting and powerful
        if self.isLeaf:
            return self.label
        # Else I have to ask one of my children to do the job
        else:
            if data[self.stump[0]] > self.stump[1]:
                return self.right.predict( data )
            else:
                return self.left.predict( data )
            
    # Get the Entropy of a node with nPos positive points and nNeg negative points
    def getEntropy( self, nPos, nNeg ):
        nTot = nPos + nNeg
        # Find the proportion of the positives and negatives in that node
        pPos = nPos/nTot
        pNeg = nNeg/nTot
        if(pPos==0 or pNeg==0):
            return float('inf')
        entropy = -1.0*(pPos*np.log(pPos)) - 1.0*(pNeg*np.log(pNeg))
        return entropy
    # implementation of LwPsatmp   
    def getStump( self, X, y ):
        # How many data points do I have at this node?
        n = len(y)
        bestObjective = 0
        bestFeat = 0
        bestThresh = 0
        cnt=0
        for i in range(len(y)):
            if y[i] == -1:
                cnt+=1
        Entropy = self.getEntropy(n-cnt,cnt)
        # For each of the features in the data
        for i in range( X.shape[1] ):
            # Do not use the same feature as used by the parent node
            if self.parent is not None and i == self.parent.stump[0]:
                continue
            # Find out all values at which we can threshold that feature
            thresh = (np.mean( X[y > 0, i] ) + np.mean( X[y < 0, i] ))/2
            nLeftPos = np.sum( y[np.logical_and( y > 0, X[:, i] <= thresh )] )
            nLeftNeg = np.sum( y[np.logical_and( y < 0, X[:, i] <= thresh )] )
            nRightPos = np.sum( y[np.logical_and( y > 0, X[:, i] > thresh )] )
            nRightNeg = np.sum( y[np.logical_and( y < 0, X[:, i] > thresh )] )
            sz_1 = (nLeftPos) + (nLeftNeg) 
            sz_2 = (nRightPos) + (nRightNeg)
            Entropy_1 =  1.0 * self.getEntropy( nLeftPos, nLeftNeg )
            Entropy_2 =  1.0 * self.getEntropy( nRightPos, nRightNeg )
            candidateObjective = wBalance * getBalance( nLeftPos + nLeftNeg, nRightPos + nRightNeg ) \
                                    + Entropy - ((sz_1 * Entropy_1)/n) - ((sz_2 * Entropy_2)/n)

            if candidateObjective > bestObjective:
                bestObjective = candidateObjective
                bestFeat = i
                bestThresh = thresh
        
        return (bestFeat, bestThresh)
            
    def train( self, X, y, maxLeafSize, maxDepth ):
        # If too few data points are present, or else if this node is too deep in the tree, make this a leaf
        if y.size < maxLeafSize or self.depth >= maxDepth:
            self.isLeaf = True
            self.label = np.mean( y )
        else:
            # This node will be split and hence it is not a leaf
            self.isLeaf = False
            # Get the best possible decision stump
            self.stump = self.getStump( X, y )
            self.left = Node( depth = self.depth + 1, parent = self )
            self.right = Node( depth = self.depth + 1, parent = self )
            # Find which points go to my left child and which go to my right child
            discriminant = X[:, self.stump[0]] - self.stump[1]
            # Train my two children recursively
            self.left.train( X[discriminant <= 0, :], y[discriminant <= 0], maxLeafSize, maxDepth )
            self.right.train( X[discriminant > 0, :], y[discriminant > 0], maxLeafSize, maxDepth )

class LwpTree:
    def __init__( self, maxLeafSize , maxDepth  ):
        self.root = Node()
        self.maxLeafSize = maxLeafSize
        self.maxDepth = maxDepth 
        
    def predict( self, xt):
        return self.root.predict( np.array(xt) )
    
    def train( self, X, y ):
        self.root.train( X, y, self.maxLeafSize, self.maxDepth )

# %%
LwPDT = LwpTree( maxLeafSize = 5, maxDepth = 4 )
LwPDT.train(x_train, y_train)
# Out:
# <ipython-input-69-49cc2ac0d2a5>:33: RuntimeWarning: invalid value encountered in log
#   entropy = -1.0*(pPos*np.log(pPos)) - 1.0*(pNeg*np.log(pNeg))

# %% [markdown]
# # Validation set accuracy using LwPStump

# %%
y_prid = []
# pridicting the validation set accuracy uding LwPstamp
for i in range(len(x_valid)):
    if(LwPDT.predict(x_valid[i]) >= 0):
        y_prid.append(1)
    else:
        y_prid.append(-1)
count = 0
for i in range(len(y_prid)):
    if(y_prid[i] == y_valid[i]):
        count = count + 1
print("Validation set accuracy using LwPStump : ",count/len(y_prid))
# Out:
# Validation set accuracy using LwPStump :  0.7648607150690941

# %% [markdown]
# # Test Set Accuracy using LwPStump

# %%
y_prid = []
# predicting the training set accuracy using LwPStamp
for i in range(len(x_test)):
    if(LwPDT.predict(x_test[i]) >= 0):
        y_prid.append(1)
    else:
        y_prid.append(-1)
count = 0
for i in range(len(y_test)):
    if(y_prid[i] == y_test[i]):
        count = count + 1
print("Test Set Accuracy using LwPStump: ")
count/len(y_test)
# Out:
# Test Set Accuracy using LwPStump:
# 0.7559627392773057
